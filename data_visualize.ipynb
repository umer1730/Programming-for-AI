# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,4*np.pi,200)
y_sin = np.sin(x)
plt.plot(x, y_sin, "b-",label = "sin")

# %%
plt.scatter(x[::10],y_sin[::10],color = "red",label="cos")
plt.legend()

# %%
plt.plot(x, y_sin, "b-",label = "sin")
plt.scatter(x[::10],y_sin[::10],color = "red",label="cos")
plt.legend()

# %%
categories = ["A","B","C","D"]
values = [5,15,7,10]
data = np.random.randn(1000)
# plotting
plt.figure(figsize=(10, 4))
plt.subplot(1,2,1)
plt.bar(categories,values, color="steelblue")
plt.subplot(1,2,2)
plt.hist(data, color="orange")
# Out:
# (array([ 14.,  48., 125., 213., 257., 201.,  96.,  35.,   9.,   2.]),
#  array([-2.64593098, -2.02890067, -1.41187035, -0.79484004, -0.17780973,
#          0.43922058,  1.0562509 ,  1.67328121,  2.29031152,  2.90734183,
#          3.52437215]),
#  <BarContainer object of 10 artists>)

# %%
name = ["ALi","Saim","Ahad","Bilal","Haseeb"]
age = [21,23,19,16,11]
plt.bar(name,age, color="blue")
plt.xlabel("Name")
plt.ylabel("Age")
plt.title("Comparison")
# Out:
# Text(0.5, 1.0, 'Comparison')

# %%
name = ["ALi","Saim","Ahad","Bilal","Haseeb"]
age = [21,23,19,16,11]
plt.bar(name,age, color="lightgreen")
plt.xlabel("Name")
plt.ylabel("Age")
plt.title("Comparison")
plt.grid(True, linestyle ="--" )

# %%
name = ["ALi","Saim","Ahad","Bilal","Haseeb"]
age = [21,23,19,16,11]
plt.bar(name,age, color="lightgreen")
plt.xlabel("Name")
plt.ylabel("Age")
plt.title("Comparison")
plt.grid(True, linestyle ="--" )
plt.legend(loc = "best")
# Out:
# C:\Users\BRAIN\AppData\Local\Temp\ipykernel_14884\3146011845.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc = "best")

# %%
name = ["ALi","Saim","Ahad","Bilal","Haseeb"]
age = [21,23,19,16,11]
plt.bar(name,age, color="lightgreen")
plt.xlabel("Name")
plt.ylabel("Age")
plt.title("Comparison")
plt.grid(True, linestyle ="--" )
plt.legend(loc = "best")
plt.xlim(0,8),plt.ylim(0,30)
# Out:
# C:\Users\BRAIN\AppData\Local\Temp\ipykernel_14884\748122186.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc = "best")
# ((0.0, 8.0), (0.0, 30.0))
